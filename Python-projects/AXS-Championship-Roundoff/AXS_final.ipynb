# %%
# importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# displaying all column contents
pd.set_option('display.max_columns', None)

# %%
# reading original dataset
read_df = pd.read_csv("basketball possessions.csv")

read_df.head()
# Out:
#              defense.teamId   defense.name            offense.teamId  \
# 0  54457dd3300969b132fcfeb4   WestVirginia  54457dd3300969b132fcfead
# 1  54457dd3300969b132fcfec9  OklahomaState  54457dd3300969b132fcfe95
# 2  54457dd3300969b132fcfeb3       Oklahoma  54457dd3300969b132fcfe9b
# 3  54457dd4300969b132fcff03    KansasState  54457dd3300969b132fcfe85
# 4  54457dd3300969b132fcfead      TexasTech  54457dd3300969b132fcfeb4
#
#    offense.name        gameResults.gameId          gameResults.date  \
# 0     TexasTech  5bd06405aeda7199391283ea  2019-01-02T00:00:00.000Z
# 1     IowaState  5bd02bbdaeda719939a79971  2019-01-02T00:00:00.000Z
# 2        Kansas  5bd0319baeda719939b048f3  2019-01-02T00:00:00.000Z
# 3   TexasAustin  5bd04203aeda719939caccc0  2019-01-02T00:00:00.000Z
# 4  WestVirginia  5bd06405aeda7199391283ea  2019-01-02T00:00:00.000Z
#
#    gameResults.awayTeamName    gameResults.awayTeamId  \
# 0    Texas Tech Red Raiders  54457dd3300969b132fcfead
# ...

# %%
# Picking variables to use
stats = read_df[["gameResults.date", "possessionId", "offense.name", "oPlayer.name", "gameResults.awayTeamScore",
                 "gameResults.homeTeamScore", "plays.0.name", "isHome", "ftMade", "ftAttempt", "foulShot",
                 "hardDouble", "pickAndRoll", "gameHalf", "sob", "eob", "ato", "zone", "press", "shotX", "shotY",
                 "shortClock"]]

stats.head()
# Out:
#            gameResults.date              possessionId  offense.name  \
# 0  2019-01-02T00:00:00.000Z  5c2dd5b785d07ba9763def5f     TexasTech
# 1  2019-01-02T00:00:00.000Z  5c2dea8f85d07ba9764e98cf     IowaState
# 2  2019-01-02T00:00:00.000Z  5c2df00c85d07ba97652e92b        Kansas
# 3  2019-01-02T00:00:00.000Z  5c2e844585d07ba976f4eb74   TexasAustin
# 4  2019-01-02T00:00:00.000Z  5c2dd5b785d07ba9763def60  WestVirginia
#
#      oPlayer.name  gameResults.awayTeamScore  gameResults.homeTeamScore  \
# 0  Davide Moretti                         62                         59
# 1   Marial Shayok                         69                         63
# 2   Dedric Lawson                         63                         70
# 3    Jaxson Hayes                         67                         47
# 4   Jordan Mccabe                         62                         59
#
#        plays.0.name  isHome  ftMade  ftAttempt  foulShot  hardDouble  \
# ...

# %%
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19088 entries, 0 to 19087
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   gameResults.date           19088 non-null  object
#  1   possessionId               19088 non-null  object
#  2   offense.name               19088 non-null  object
#  3   oPlayer.name               19088 non-null  object
#  4   gameResults.awayTeamScore  19088 non-null  int64
#  5   gameResults.homeTeamScore  19088 non-null  int64
#  6   plays.0.name               19088 non-null  object
#  7   isHome                     19088 non-null  bool
#  8   ftMade                     19088 non-null  int64
#  9   ftAttempt                  19088 non-null  int64
#  10  foulShot                   19088 non-null  bool
#  11  hardDouble                 19088 non-null  bool
#  12  pickAndRoll                19088 non-null  bool
# ...

# %%
stats.describe(include=bool)
# Out:
#        isHome foulShot hardDouble pickAndRoll    sob    eob    ato   zone  \
# count   19088    19088      19088       19088  19088  19088  19088  19088
# unique      2        2          2           2      2      2      2      2
# top      True    False      False       False  False  False  False  False
# freq     9686    18130      18735       18904  18563  18063  16719  17325
#
#         press shortClock
# count   19088      19088
# unique      2          2
# top     False      False
# freq    18234      17911
